# %%
import pandas as pd
pd.set_option('display.max_columns', 80)

# %%
sonido = pd.read_csv("../dataset/noise_contamination.csv")

# %%
sonido
# Out:
#           split  sensor_id audio_filename  annotator_id  borough  block  \
# 0          test          0  00_026884.wav            -6        1    547
# 1          test          0  00_026884.wav            -4        1    547
# 2          test          0  00_026884.wav            -3        1    547
# 3          test          0  00_026884.wav            -1        1    547
# 4          test          0  00_026884.wav             0        1    547
# ...         ...        ...            ...           ...      ...    ...
# 62017  validate         46  46_020807.wav          5399        1    559
# 62018  validate         46  46_020807.wav          5424        1    559
# 62019  validate         46  46_020853.wav          5337        1    559
# 62020  validate         46  46_020853.wav          5365        1    559
# 62021  validate         46  46_020853.wav          5373        1    559
#
#        latitude  longitude  year  week  day  hour  \
# 0      40.72951  -73.99388  2019    43    4     8
# ...

# %%
sonido.columns
# Out:
# Index(['split', 'sensor_id', 'audio_filename', 'annotator_id', 'borough',
#        'block', 'latitude', 'longitude', 'year', 'week', 'day', 'hour',
#        '1-1_small-sounding-engine_presence',
#        '1-2_medium-sounding-engine_presence',
#        '1-3_large-sounding-engine_presence',
#        '1-X_engine-of-uncertain-size_presence', '2-1_rock-drill_presence',
#        '2-2_jackhammer_presence', '2-3_hoe-ram_presence',
#        '2-4_pile-driver_presence',
#        '2-X_other-unknown-impact-machinery_presence',
#        '3-1_non-machinery-impact_presence', '4-1_chainsaw_presence',
#        '4-2_small-medium-rotating-saw_presence',
#        '4-3_large-rotating-saw_presence',
#        '4-X_other-unknown-powered-saw_presence', '5-1_car-horn_presence',
#        '5-2_car-alarm_presence', '5-3_siren_presence',
#        '5-4_reverse-beeper_presence',
#        '5-X_other-unknown-alert-signal_presence',
#        '6-1_stationary-music_presence', '6-2_mobile-music_presence',
# ...

# %% [markdown]
# Decidimos dejar las columnas:
# - year
# - week
# - day
# - hour
# - borough
# - block
# - latitude
# - longitude

# %% [markdown]
# Antes de eliminar las columnas, hacemos un filtrado por la columna "annotator_id", en dónde los valores sean 0, ya que, según el diccionario del Dataset, el 0 se define cómo la verdad básica acordada por el equipo SONYC

# %%
sonido[sonido["annotator_id"] == 0]
# Out:
#           split  sensor_id audio_filename  annotator_id  borough  block  \
# 4          test          0  00_026884.wav             0        1    547
# 12         test          0  00_026919.wav             0        1    547
# 18         test          0  00_027065.wav             0        1    547
# 28         test          0  00_027096.wav             0        1    547
# 36         test          0  00_027130.wav             0        1    547
# ...         ...        ...            ...           ...      ...    ...
# 61602  validate         46  46_010845.wav             0        1    559
# 61608  validate         46  46_010846.wav             0        1    559
# 61621  validate         46  46_010902.wav             0        1    559
# 61629  validate         46  46_010903.wav             0        1    559
# 61637  validate         46  46_010968.wav             0        1    559
#
#        latitude  longitude  year  week  day  hour  \
# 4      40.72951  -73.99388  2019    43    4     8
# ...

# %%
sonido = sonido[sonido["annotator_id"] == 0]

# %% [markdown]
# # Eliminación de columnas innecesarias para nuestro análisis

# %%
sonido.drop("split",axis=1) # La columna split no nos aportaba información relevante, ya que diferenciaba si la muestra de sonido fué un testeo, una validación o una prueba, en nuestro caso, no era relevante.
# Out:
#        sensor_id audio_filename  annotator_id  borough  block  latitude  \
# 4              0  00_026884.wav             0        1    547  40.72951
# 12             0  00_026919.wav             0        1    547  40.72951
# 18             0  00_027065.wav             0        1    547  40.72951
# 28             0  00_027096.wav             0        1    547  40.72951
# 36             0  00_027130.wav             0        1    547  40.72951
# ...          ...            ...           ...      ...    ...       ...
# 61602         46  46_010845.wav             0        1    559  40.73365
# 61608         46  46_010846.wav             0        1    559  40.73365
# 61621         46  46_010902.wav             0        1    559  40.73365
# 61629         46  46_010903.wav             0        1    559  40.73365
# 61637         46  46_010968.wav             0        1    559  40.73365
#
#        longitude  year  week  day  hour  1-1_small-sounding-engine_presence  \
# ...

# %%
sonido = sonido.drop("split",axis=1)

# %%
sonido.drop("sensor_id",axis=1) # El identificador del sensor tampoco nos importa mucho, ya que no tenemos forma de relacionarlo con otro dataset
# Out:
#       audio_filename  annotator_id  borough  block  latitude  longitude  year  \
# 4      00_026884.wav             0        1    547  40.72951  -73.99388  2019
# 12     00_026919.wav             0        1    547  40.72951  -73.99388  2019
# 18     00_027065.wav             0        1    547  40.72951  -73.99388  2019
# 28     00_027096.wav             0        1    547  40.72951  -73.99388  2019
# 36     00_027130.wav             0        1    547  40.72951  -73.99388  2019
# ...              ...           ...      ...    ...       ...        ...   ...
# 61602  46_010845.wav             0        1    559  40.73365  -73.98879  2018
# 61608  46_010846.wav             0        1    559  40.73365  -73.98879  2018
# 61621  46_010902.wav             0        1    559  40.73365  -73.98879  2018
# 61629  46_010903.wav             0        1    559  40.73365  -73.98879  2018
# 61637  46_010968.wav             0        1    559  40.73365  -73.98879  2018
#
# ...

# %%
sonido = sonido.drop("sensor_id",axis=1)

# %%
sonido.drop("audio_filename", axis=1) # El nombre del archivo no nos proporciona tampoco un dato muy importante, ya que tiene un nombre poco descriptivo al respecto
# Out:
#        annotator_id  borough  block  latitude  longitude  year  week  day  \
# 4                 0        1    547  40.72951  -73.99388  2019    43    4
# 12                0        1    547  40.72951  -73.99388  2019    20    1
# 18                0        1    547  40.72951  -73.99388  2019    35    6
# 28                0        1    547  40.72951  -73.99388  2019    31    1
# 36                0        1    547  40.72951  -73.99388  2019    40    0
# ...             ...      ...    ...       ...        ...   ...   ...  ...
# 61602             0        1    559  40.73365  -73.98879  2018    43    4
# 61608             0        1    559  40.73365  -73.98879  2018    49    3
# 61621             0        1    559  40.73365  -73.98879  2018    39    4
# 61629             0        1    559  40.73365  -73.98879  2018    43    5
# 61637             0        1    559  40.73365  -73.98879  2018    46    4
#
#        hour  1-1_small-sounding-engine_presence  \
# ...

# %%
sonido = sonido.drop("audio_filename", axis=1)

# %%
sonido.drop("annotator_id", axis=1) # Esta columna nos sirvió inicialmente para hacer un filtrado, pero en este momento, sólo contiene 0, por lo cuál ya no nos proporciona datos útiles
# Out:
#        borough  block  latitude  longitude  year  week  day  hour  \
# 4            1    547  40.72951  -73.99388  2019    43    4     8
# 12           1    547  40.72951  -73.99388  2019    20    1    20
# 18           1    547  40.72951  -73.99388  2019    35    6    11
# 28           1    547  40.72951  -73.99388  2019    31    1     9
# 36           1    547  40.72951  -73.99388  2019    40    0    13
# ...        ...    ...       ...        ...   ...   ...  ...   ...
# 61602        1    559  40.73365  -73.98879  2018    43    4    23
# 61608        1    559  40.73365  -73.98879  2018    49    3    22
# 61621        1    559  40.73365  -73.98879  2018    39    4    20
# 61629        1    559  40.73365  -73.98879  2018    43    5    22
# 61637        1    559  40.73365  -73.98879  2018    46    4    19
#
#        1-1_small-sounding-engine_presence  \
# 4                                       0
# 12                                      0
# 18                                      0
# ...

# %%
sonido = sonido.drop("annotator_id", axis=1)

# %% [markdown]
# Cómo mencioné anteriormente, las columnas: "borough	block latitude	longitude year week	day	hour" si nos van a servir, entonces las dejamos.

# %% [markdown]
# Nuestro dataset entonces queda de la forma

# %%
sonido
# Out:
#        borough  block  latitude  longitude  year  week  day  hour  \
# 4            1    547  40.72951  -73.99388  2019    43    4     8
# 12           1    547  40.72951  -73.99388  2019    20    1    20
# 18           1    547  40.72951  -73.99388  2019    35    6    11
# 28           1    547  40.72951  -73.99388  2019    31    1     9
# 36           1    547  40.72951  -73.99388  2019    40    0    13
# ...        ...    ...       ...        ...   ...   ...  ...   ...
# 61602        1    559  40.73365  -73.98879  2018    43    4    23
# 61608        1    559  40.73365  -73.98879  2018    49    3    22
# 61621        1    559  40.73365  -73.98879  2018    39    4    20
# 61629        1    559  40.73365  -73.98879  2018    43    5    22
# 61637        1    559  40.73365  -73.98879  2018    46    4    19
#
#        1-1_small-sounding-engine_presence  \
# 4                                       0
# 12                                      0
# 18                                      0
# ...

# %% [markdown]
# Para trabajar de forma más comoda, voy a definir otro dataframe, que sólo contenga el resto de columnas a partir de "hour"

# %%
lista_con_nombres_de_columnas = []
for columna in sonido.columns:
    lista_con_nombres_de_columnas.append(columna)

print(lista_con_nombres_de_columnas)
# Out:
# ['borough', 'block', 'latitude', 'longitude', 'year', 'week', 'day', 'hour', '1-1_small-sounding-engine_presence', '1-2_medium-sounding-engine_presence', '1-3_large-sounding-engine_presence', '1-X_engine-of-uncertain-size_presence', '2-1_rock-drill_presence', '2-2_jackhammer_presence', '2-3_hoe-ram_presence', '2-4_pile-driver_presence', '2-X_other-unknown-impact-machinery_presence', '3-1_non-machinery-impact_presence', '4-1_chainsaw_presence', '4-2_small-medium-rotating-saw_presence', '4-3_large-rotating-saw_presence', '4-X_other-unknown-powered-saw_presence', '5-1_car-horn_presence', '5-2_car-alarm_presence', '5-3_siren_presence', '5-4_reverse-beeper_presence', '5-X_other-unknown-alert-signal_presence', '6-1_stationary-music_presence', '6-2_mobile-music_presence', '6-3_ice-cream-truck_presence', '6-X_music-from-uncertain-source_presence', '7-1_person-or-small-group-talking_presence', '7-2_person-or-small-group-shouting_presence', '7-3_large-crowd_presence', '7-4_amplified-speech_pre
# ...

# %%
lista_con_nombres_de_columnas = ['1-1_small-sounding-engine_presence', '1-2_medium-sounding-engine_presence', '1-3_large-sounding-engine_presence', '1-X_engine-of-uncertain-size_presence', '2-1_rock-drill_presence', '2-2_jackhammer_presence', '2-3_hoe-ram_presence', '2-4_pile-driver_presence', '2-X_other-unknown-impact-machinery_presence', '3-1_non-machinery-impact_presence', '4-1_chainsaw_presence', '4-2_small-medium-rotating-saw_presence', '4-3_large-rotating-saw_presence', '4-X_other-unknown-powered-saw_presence', '5-1_car-horn_presence', '5-2_car-alarm_presence', '5-3_siren_presence', '5-4_reverse-beeper_presence', '5-X_other-unknown-alert-signal_presence', '6-1_stationary-music_presence', '6-2_mobile-music_presence', '6-3_ice-cream-truck_presence', '6-X_music-from-uncertain-source_presence', '7-1_person-or-small-group-talking_presence', '7-2_person-or-small-group-shouting_presence', '7-3_large-crowd_presence', '7-4_amplified-speech_presence', '7-X_other-unknown-human-voice_presence', '8-1_dog-barking-whining_presence', '1-1_small-sounding-engine_proximity', '1-2_medium-sounding-engine_proximity', '1-3_large-sounding-engine_proximity', '1-X_engine-of-uncertain-size_proximity', '2-1_rock-drill_proximity', '2-2_jackhammer_proximity', '2-3_hoe-ram_proximity', '2-4_pile-driver_proximity', '2-X_other-unknown-impact-machinery_proximity', '3-1_non-machinery-impact_proximity', '4-1_chainsaw_proximity', '4-2_small-medium-rotating-saw_proximity', '4-3_large-rotating-saw_proximity', '4-X_other-unknown-powered-saw_proximity', '5-1_car-horn_proximity', '5-2_car-alarm_proximity', '5-3_siren_proximity', '5-4_reverse-beeper_proximity', '5-X_other-unknown-alert-signal_proximity', '6-1_stationary-music_proximity', '6-2_mobile-music_proximity', '6-3_ice-cream-truck_proximity', '6-X_music-from-uncertain-source_proximity', '7-1_person-or-small-group-talking_proximity', '7-2_person-or-small-group-shouting_proximity', '7-3_large-crowd_proximity', '7-4_amplified-speech_proximity', '7-X_other-unknown-human-voice_proximity', '8-1_dog-barking-whining_proximity', '1_engine_presence', '2_machinery-impact_presence', '3_non-machinery-impact_presence', '4_powered-saw_presence', '5_alert-signal_presence', '6_music_presence', '7_human-voice_presence', '8_dog_presence']

# %%
sonido_dataset_parcial = sonido[lista_con_nombres_de_columnas]

# %%
sonido_dataset_parcial.head(1)
# Out:
#    1-1_small-sounding-engine_presence  1-2_medium-sounding-engine_presence  \
# 4                                   0                                    1
#
#    1-3_large-sounding-engine_presence  1-X_engine-of-uncertain-size_presence  \
# 4                                   1                                      0
#
#    2-1_rock-drill_presence  2-2_jackhammer_presence  2-3_hoe-ram_presence  \
# 4                        0                        0                     0
#
#    2-4_pile-driver_presence  2-X_other-unknown-impact-machinery_presence  \
# 4                         0                                            0
#
#    3-1_non-machinery-impact_presence  4-1_chainsaw_presence  \
# 4                                  1                      0
#
#    4-2_small-medium-rotating-saw_presence  4-3_large-rotating-saw_presence  \
# 4                                       0                                0
#
#    4-X_other-unknown-powered-saw_presence  5-1_car-horn_presence  \
# ...

# %%
lista_con_columnas_a_dejar = ['borough', 'block', 'latitude', 'longitude', 'year', 'week', 'day', 'hour',
    "1-1_small-sounding-engine_presence", "1-2_medium-sounding-engine_presence", 
"1-3_large-sounding-engine_presence", '1-X_engine-of-uncertain-size_presence', '5-1_car-horn_presence', '5-2_car-alarm_presence', '6-2_mobile-music_presence', '6-X_music-from-uncertain-source_presence', '7-1_person-or-small-group-talking_presence',
       '7-2_person-or-small-group-shouting_presence',
       '7-3_large-crowd_presence', '1-1_small-sounding-engine_proximity',
       '1-2_medium-sounding-engine_proximity',
       '1-3_large-sounding-engine_proximity', "1_engine_presence"]

# %%
sonido[lista_con_columnas_a_dejar]
# Out:
#        borough  block  latitude  longitude  year  week  day  hour  \
# 4            1    547  40.72951  -73.99388  2019    43    4     8
# 12           1    547  40.72951  -73.99388  2019    20    1    20
# 18           1    547  40.72951  -73.99388  2019    35    6    11
# 28           1    547  40.72951  -73.99388  2019    31    1     9
# 36           1    547  40.72951  -73.99388  2019    40    0    13
# ...        ...    ...       ...        ...   ...   ...  ...   ...
# 61602        1    559  40.73365  -73.98879  2018    43    4    23
# 61608        1    559  40.73365  -73.98879  2018    49    3    22
# 61621        1    559  40.73365  -73.98879  2018    39    4    20
# 61629        1    559  40.73365  -73.98879  2018    43    5    22
# 61637        1    559  40.73365  -73.98879  2018    46    4    19
#
#        1-1_small-sounding-engine_presence  \
# 4                                       0
# 12                                      0
# 18                                      0
# ...

# %%
sonido = sonido[lista_con_columnas_a_dejar]

# %% [markdown]
# # Renombrar columnas

# %%
sonido.columns
# Out:
# Index(['borough', 'block', 'latitude', 'longitude', 'year', 'week', 'day',
#        'hour', '1-1_small-sounding-engine_presence',
#        '1-2_medium-sounding-engine_presence',
#        '1-3_large-sounding-engine_presence',
#        '1-X_engine-of-uncertain-size_presence', '5-1_car-horn_presence',
#        '5-2_car-alarm_presence', '6-2_mobile-music_presence',
#        '6-X_music-from-uncertain-source_presence',
#        '7-1_person-or-small-group-talking_presence',
#        '7-2_person-or-small-group-shouting_presence',
#        '7-3_large-crowd_presence', '1-1_small-sounding-engine_proximity',
#        '1-2_medium-sounding-engine_proximity',
#        '1-3_large-sounding-engine_proximity', '1_engine_presence'],
#       dtype='object')

# %%
diccionario_para_renombrar = {'borough':"distrito", 'block':"bloque", 'latitude':"latitud", 'longitude':"longitud", 'year':'año', 'week':"semana", 'day':"dia",
       'hour':"hora", '1-1_small-sounding-engine_presence':'motores_pequeños',
'1-2_medium-sounding-engine_presence':'motores_medianos',
'1-3_large-sounding-engine_presence':'motores_grandes',
'1-X_engine-of-uncertain-size_presence':'motores_tamaño_desconocido',
'5-1_car-horn_presence':'bocinas_auto',
'5-2_car-alarm_presence':'alarmas_de_auto',
'6-2_mobile-music_presence':'música_movil',
'6-X_music-from-uncertain-source_presence':'música_de_origen_desconocido',
'7-1_person-or-small-group-talking_presence':'persona_o_grupo_pequeño_hablando',
'7-2_person-or-small-group-shouting_presence':'persona_o_grupo_pequeño_gritando',
'7-3_large-crowd_presence':'multitud_grande',
'1-1_small-sounding-engine_proximity':'proximidad_motores_pequeños',
'1-2_medium-sounding-engine_proximity':'proximidad_motores_medianos',
'1-3_large-sounding-engine_proximity':'proximidad_motores_grandes',
'1_engine_presence':'motores'}

# %%
sonido.rename(diccionario_para_renombrar, axis=1)
# Out:
#        distrito  bloque   latitud  longitud   año  semana  dia  hora  \
# 4             1     547  40.72951 -73.99388  2019      43    4     8
# 12            1     547  40.72951 -73.99388  2019      20    1    20
# 18            1     547  40.72951 -73.99388  2019      35    6    11
# 28            1     547  40.72951 -73.99388  2019      31    1     9
# 36            1     547  40.72951 -73.99388  2019      40    0    13
# ...         ...     ...       ...       ...   ...     ...  ...   ...
# 61602         1     559  40.73365 -73.98879  2018      43    4    23
# 61608         1     559  40.73365 -73.98879  2018      49    3    22
# 61621         1     559  40.73365 -73.98879  2018      39    4    20
# 61629         1     559  40.73365 -73.98879  2018      43    5    22
# 61637         1     559  40.73365 -73.98879  2018      46    4    19
#
#        motores_pequeños  motores_medianos  motores_grandes  \
# 4                     0                 1                1
# ...

# %%
sonido = sonido.rename(diccionario_para_renombrar, axis=1)

# %%
sonido = sonido.reset_index().drop("index",axis=1)

# %%
sonido.to_csv("../Datasets/dataset_ruido_post_etl_inicial.csv")
