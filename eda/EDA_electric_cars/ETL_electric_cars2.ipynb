# %%
#Importamos librerias necesarias 
import pandas as pd

# %%
#Leemos los datasets
df_electric = pd.read_csv('Datasets\ElectricCarData_Clean.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\pauda\AppData\Local\Temp\ipykernel_24900\2692396169.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df_electric = pd.read_csv('Datasets\ElectricCarData_Clean.csv')

# %%
df_electric
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0         450              161            940         Yes        AWD
# 1         270              167            250         Yes        RWD
# 2         400              181            620         Yes        AWD
# 3         360              206            560         Yes        RWD
# 4         170              168            190         Yes        RWD
# ..        ...              ...            ...         ...        ...
# 98        330              191            440         Yes        FWD
# 99        335              258            540         Yes        AWD
# 100       325              194            440         Yes        AWD
# 101       375              232            450         Yes        AWD
# 102       400              238            480         Yes        AWD
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# 0    Type 2 CCS      Sedan       D      5      55480
# 1    Type 2 CCS  Hatchback       C      5      30000
# 2    Type 2 CCS   Liftback       D      5      56440
# 3    Type 2 CCS        SUV       D      5      68040
# 4    Type 2 CCS  Hatchback       B      4      32997
# ..          ...        ...     ...    ...        ...
# 98   Type 2 CCS  Hatchback       C      5      45000
# 99   Type 2 CCS        SUV       E      5      96050
# 100  Type 2 CCS  Hatchback       C      5      50000
# 101  Type 2 CCS  Hatchback       C      5      65000
# 102  Type 2 CCS        SUV       E      5      62000
#
# [103 rows x 14 columns]

# %%
df_electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %% [markdown]
# ### Lista con los modelos de autos aprovados para ser taxis en Nueva York:
#
# ### Accessible Vehicles
# Chrysler Pacifica Accessible, Rear Entry TLC Yellow Taxi Conversion (FR Conversions)
# Chrysler Voyager/Pacifica Accessible, Rear Entry ADA Compliant (TransitWorks/Diverge)
# Chrysler Voyager Accessible, Rear Entry Commercial VT Model (BraunAbility)
# Chrysler Voyager Accessible, Side Entry Commercial VT Model (BraunAbility)
# Ford Transit Connect Accessible, Rear Entry ADA Compliant (TransitWorks/Diverge)
# Mercedes-Benz Metris Accessible, Rear Entry ADA Compliant (TransitWorks/Diverge)
# Nissan NV200 Accessible, Rear Entry (BraunAbility Commercial VT Model)
# Toyota Sienna Hybrid Accessible, Rear Entry Commercial VT Model (BraunAbility)
# Toyota Sienna Hybrid Accessible, Rear Entry TLC Yellow Taxi Conversion (FR Conversions)
# Toyota Sienna Hybrid Accessible, Rear Entry Commercial (Vantage Mobility)
# ### Electric Vehicles (EVs)
# Ford Mustang Mach Electric Vehicle (EV)
# Hyundai Ioniq 5 Electric Vehicle (EV)
# Kia Niro Electric Vehicle (EV)
# Tesla Model 3 RWD Electric Vehicle (EV)
# Tesla Model 3 Long Range Electric Vehicle (EV)
# Tesla Model Y Long Range AWD Electric Vehicle (EV)
# Toyota bZ4X Electric Vehicle (EV)
# ### Hybrids
# Ford Escape Hybrid
# Honda Accord Hybrid
# Kia Niro Hybrid
# Kia Niro Plug-in Hybrid Electric Vehicle (PHEV)
# Toyota Avalon Hybrid
# Toyota Camry Hybrid
# Toyota Highlander Hybrid
# Toyota Prius Hybrid
# Toyota Prius V
# Toyota RAV4 Hybrid
# Toyota Sienna Hybrid
# Toyota Venza Hybrid
# Standard Vehicles
# Ford Escape
# Nissan Altima
# Toyota Camry
# Toyota Crown
# Toyota Highlander
# Toyota RAV4

# %%
df_electric['Brand'].unique()
# Out:
# array(['Tesla ', 'Volkswagen ', 'Polestar ', 'BMW ', 'Honda ', 'Lucid ',
#        'Peugeot ', 'Audi ', 'Mercedes ', 'Nissan ', 'Hyundai ',
#        'Porsche ', 'MG ', 'Mini ', 'Opel ', 'Skoda ', 'Volvo ', 'Kia ',
#        'Renault ', 'Mazda ', 'Lexus ', 'CUPRA ', 'SEAT ', 'Lightyear ',
#        'Aiways ', 'DS ', 'Citroen ', 'Jaguar ', 'Ford ', 'Byton ',
#        'Sono ', 'Smart ', 'Fiat '], dtype=object)

# %% [markdown]
# Chrysler | Ford | Mercedes-Benz | Nissan | Toyota | Hyundai | Kia | Tesla | Toyota | Honda

# %%
# Lista de las marcas que queremos filtrar
marcas_filtradas = ['Chrysler ','Ford ','Mercedes-Benz ','Nissan ','Toyota ','Hyundai ','Kia ','Tesla ','Toyota ','Honda ']
# Filtrar el DataFrame
df_filtrado_marcas = df_electric[df_electric['Brand'].isin(marcas_filtradas)]

# %%
df_filtrado_marcas
# Out:
#         Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0      Tesla     Model 3 Long Range Dual Motor       4.6           233
# 4      Honda                                e        9.5           145
# 8      Tesla       Model 3 Standard Range Plus       5.6           225
# 11    Nissan                             Leaf        7.9           144
# 12   Hyundai              Kona Electric 64 kWh       7.9           167
# 14   Hyundai                    IONIQ Electric       9.7           165
# 21     Tesla     Model Y Long Range Dual Motor       5.1           217
# 24     Tesla    Model 3 Long Range Performance       3.4           261
# 31       Kia                     e-Niro 64 kWh       7.8           167
# 33     Tesla              Cybertruck Tri Motor       3.0           210
# 35    Nissan                           Leaf e+       7.3           157
# 40     Tesla                Model S Long Range       3.8           250
# 41   Hyundai              Kona Electric 39 kWh       9.9           155
# 45       Kia                     e-Soul 64 kWh       7.9           167
# 51     Tesla                         Roadster        2.1           410
# 54     Tesla                Model X Long Range       4.6           250
# 55     Honda                         e Advance       8.3           145
# 59     Tesla               Model S Performance       2.5           261
# 61     Tesla    Model Y Long Range Performance       3.7           241
# 62    Nissan                       Ariya 87kWh       7.6           160
# 64      Ford             Mustang Mach-E ER RWD       7.0           180
# 66    Nissan                   e-NV200 Evalia       14.0           123
# 67     Tesla             Cybertruck Dual Motor       5.0           190
# 69      Ford             Mustang Mach-E ER AWD       6.0           180
# 75       Kia                     e-Niro 39 kWh       9.8           155
# 78      Ford             Mustang Mach-E SR AWD       6.0           180
# 81     Tesla               Model X Performance       2.8           250
# 83      Ford             Mustang Mach-E SR RWD       6.6           180
# 86     Tesla           Cybertruck Single Motor       7.0           180
# 92       Kia                     e-Soul 64 kWh       7.9           167
# 93    Nissan               Ariya e-4ORCE 87kWh       5.7           200
# 96       Kia                     e-Soul 39 kWh       9.9           157
# 98    Nissan                       Ariya 63kWh       7.5           160
# 100   Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101   Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0         450              161            940         Yes        AWD
# 4         170              168            190         Yes        RWD
# 8         310              153            650         Yes        RWD
# 11        220              164            230         Yes        FWD
# 12        400              160            380         Yes        FWD
# 14        250              153            210         Yes        FWD
# 21        425              171            930         Yes        AWD
# 24        435              167            910         Yes        AWD
# 31        370              173            350         Yes        FWD
# 33        750              267            710         Yes        AWD
# 35        325              172            390         Yes        FWD
# 40        515              184            560         Yes        AWD
# 41        255              154            210         Yes        FWD
# 45        365              175            340         Yes        FWD
# 51        970              206            920         Yes        AWD
# 54        450              211            490         Yes        AWD
# 55        170              168            190         Yes        RWD
# 59        505              188            550         Yes        AWD
# 61        410              177            900         Yes        AWD
# 62        440              198            520         Yes        FWD
# 64        450              200            430         Yes        RWD
# 66        190              200            190         Yes        FWD
# 67        460              261            710         Yes        AWD
# 69        430              209            410         Yes        AWD
# 75        235              167            230         Yes        FWD
# 78        340              206            360         Yes        AWD
# 81        440              216            480         Yes        AWD
# 83        360              194            380         Yes        RWD
# 86        390              256            740         Yes        RWD
# 92        365              175            320         Yes        FWD
# 93        420              207            500         Yes        AWD
# 96        230              170            220         Yes        FWD
# 98        330              191            440         Yes        FWD
# 100       325              194            440         Yes        AWD
# 101       375              232            450         Yes        AWD
#
#            PlugType  BodyStyle Segment  Seats  PriceEuro
# 0        Type 2 CCS      Sedan       D      5      55480
# 4        Type 2 CCS  Hatchback       B      4      32997
# 8        Type 2 CCS      Sedan       D      5      46380
# 11   Type 2 CHAdeMO  Hatchback       C      5      29234
# 12       Type 2 CCS        SUV       B      5      40795
# 14       Type 2 CCS   Liftback       C      5      34459
# 21       Type 2 CCS        SUV       D      7      58620
# 24       Type 2 CCS      Sedan       D      5      61480
# 31       Type 2 CCS        SUV       C      5      38105
# 33       Type 2 CCS     Pickup       N      6      75000
# 35   Type 2 CHAdeMO  Hatchback       C      5      37237
# 40           Type 2   Liftback       F      5      79990
# 41       Type 2 CCS        SUV       B      5      33971
# 45       Type 2 CCS        SUV       B      5      36837
# 51       Type 2 CCS     Cabrio       S      4     215000
# 54           Type 2        SUV       F      7      85990
# 55       Type 2 CCS  Hatchback       B      4      35921
# 59           Type 2   Liftback       F      5      96990
# 61       Type 2 CCS        SUV       D      7      65620
# 62       Type 2 CCS  Hatchback       C      5      50000
# 64       Type 2 CCS        SUV       D      5      54475
# 66   Type 1 CHAdeMO        SPV       N      7      33246
# 67       Type 2 CCS     Pickup       N      6      55000
# 69       Type 2 CCS        SUV       D      5      62900
# 75       Type 2 CCS        SUV       C      5      34400
# 78       Type 2 CCS        SUV       D      5      54000
# 81           Type 2        SUV       F      7     102990
# 83       Type 2 CCS        SUV       D      5      46900
# 86       Type 2 CCS     Pickup       N      6      45000
# 92       Type 2 CCS        SUV       B      5      36837
# 93       Type 2 CCS  Hatchback       C      5      57500
# 96       Type 2 CCS        SUV       B      5      33133
# 98       Type 2 CCS  Hatchback       C      5      45000
# 100      Type 2 CCS  Hatchback       C      5      50000
# 101      Type 2 CCS  Hatchback       C      5      65000

# %%
#Filtramos por modelos 

df_filtrado_marcas['Model'].unique()
# Out:
# array(['Model 3 Long Range Dual Motor', 'e ',
#        'Model 3 Standard Range Plus', 'Leaf ', 'Kona Electric 64 kWh',
#        'IONIQ Electric', 'Model Y Long Range Dual Motor',
#        'Model 3 Long Range Performance', 'e-Niro 64 kWh',
#        'Cybertruck Tri Motor', 'Leaf e+', 'Model S Long Range',
#        'Kona Electric 39 kWh', 'e-Soul 64 kWh', 'Roadster ',
#        'Model X Long Range', 'e Advance', 'Model S Performance',
#        'Model Y Long Range Performance', 'Ariya 87kWh',
#        'Mustang Mach-E ER RWD', 'e-NV200 Evalia ',
#        'Cybertruck Dual Motor', 'Mustang Mach-E ER AWD', 'e-Niro 39 kWh',
#        'Mustang Mach-E SR AWD', 'Model X Performance',
#        'Mustang Mach-E SR RWD', 'Cybertruck Single Motor',
#        'Ariya e-4ORCE 87kWh', 'e-Soul 39 kWh', 'Ariya 63kWh',
#        'Ariya e-4ORCE 63kWh', 'Ariya e-4ORCE 87kWh Performance'],
#       dtype=object)

# %% [markdown]
# Modelos que se aceptan para taxis > Pacifica  |  Voyager | Transit | Metris | NV200 | Sienna | Mustang | Ioniq | Niro | Model 3 | Model Y | bZ4X | Escape | Accord | Niro | Avalon | Camry | Highlander | Prius | RAV4 | Sienna | Venza | Escape | Altima | Camry | Crown

# %%
#filtramos el dataset por modelos de autos 
# Lista de palabras clave
palabras_clave = [
    'Pacifica', 'Voyager', 'Transit', 'Metris', 'NV200', 'Sienna', 'Mustang',
    'Ioniq', 'Niro', 'Model 3', 'Model Y', 'bZ4X', 'Escape', 'Accord', 'Avalon',
    'Camry', 'Highlander', 'Prius', 'RAV4', 'Venza', 'Altima', 'Crown'
]

# Crear una expresión regular que coincida con cualquiera de las palabras clave
expresion_regular = '|'.join(palabras_clave)

# Filtrar el DataFrame
df_filtrado_modelos = df_filtrado_marcas[df_filtrado_marcas['Model'].str.contains(expresion_regular, case=False, na=False)]

# %%
df_filtrado_modelos
# Out:
#        Brand                           Model  AccelSec  TopSpeed_KmH  \
# 0     Tesla    Model 3 Long Range Dual Motor       4.6           233
# 8     Tesla      Model 3 Standard Range Plus       5.6           225
# 14  Hyundai                   IONIQ Electric       9.7           165
# 21    Tesla    Model Y Long Range Dual Motor       5.1           217
# 24    Tesla   Model 3 Long Range Performance       3.4           261
# 31      Kia                    e-Niro 64 kWh       7.8           167
# 61    Tesla   Model Y Long Range Performance       3.7           241
# 64     Ford            Mustang Mach-E ER RWD       7.0           180
# 66   Nissan                  e-NV200 Evalia       14.0           123
# 69     Ford            Mustang Mach-E ER AWD       6.0           180
# 75      Kia                    e-Niro 39 kWh       9.8           155
# 78     Ford            Mustang Mach-E SR AWD       6.0           180
# 83     Ford            Mustang Mach-E SR RWD       6.6           180
#
#     Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0        450              161            940         Yes        AWD
# 8        310              153            650         Yes        RWD
# 14       250              153            210         Yes        FWD
# 21       425              171            930         Yes        AWD
# 24       435              167            910         Yes        AWD
# 31       370              173            350         Yes        FWD
# 61       410              177            900         Yes        AWD
# 64       450              200            430         Yes        RWD
# 66       190              200            190         Yes        FWD
# 69       430              209            410         Yes        AWD
# 75       235              167            230         Yes        FWD
# 78       340              206            360         Yes        AWD
# 83       360              194            380         Yes        RWD
#
#           PlugType BodyStyle Segment  Seats  PriceEuro
# 0       Type 2 CCS     Sedan       D      5      55480
# 8       Type 2 CCS     Sedan       D      5      46380
# 14      Type 2 CCS  Liftback       C      5      34459
# 21      Type 2 CCS       SUV       D      7      58620
# 24      Type 2 CCS     Sedan       D      5      61480
# 31      Type 2 CCS       SUV       C      5      38105
# 61      Type 2 CCS       SUV       D      7      65620
# 64      Type 2 CCS       SUV       D      5      54475
# 66  Type 1 CHAdeMO       SPV       N      7      33246
# 69      Type 2 CCS       SUV       D      5      62900
# 75      Type 2 CCS       SUV       C      5      34400
# 78      Type 2 CCS       SUV       D      5      54000
# 83      Type 2 CCS       SUV       D      5      46900

# %%
df_filtrado_modelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 83
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            13 non-null     object
#  1   Model            13 non-null     object
#  2   AccelSec         13 non-null     float64
#  3   TopSpeed_KmH     13 non-null     int64
#  4   Range_Km         13 non-null     int64
#  5   Efficiency_WhKm  13 non-null     int64
#  6   FastCharge_KmH   13 non-null     object
#  7   RapidCharge      13 non-null     object
#  8   PowerTrain       13 non-null     object
#  9   PlugType         13 non-null     object
#  10  BodyStyle        13 non-null     object
#  11  Segment          13 non-null     object
#  12  Seats            13 non-null     int64
#  13  PriceEuro        13 non-null     int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.5+ KB

# %%
df_filtrado_modelos.shape
# Out:
# (13, 14)

# %%
#Eliminamos columnas que no necesitamos 
df_electric2 = df_filtrado_modelos.drop(columns=['AccelSec', 'TopSpeed_KmH', 'Efficiency_WhKm', 'FastCharge_KmH','RapidCharge', 'PowerTrain','Segment','Seats'], axis=1)

# %%
df_electric2
# Out:
#        Brand                           Model  Range_Km        PlugType  \
# 0     Tesla    Model 3 Long Range Dual Motor       450      Type 2 CCS
# 8     Tesla      Model 3 Standard Range Plus       310      Type 2 CCS
# 14  Hyundai                   IONIQ Electric       250      Type 2 CCS
# 21    Tesla    Model Y Long Range Dual Motor       425      Type 2 CCS
# 24    Tesla   Model 3 Long Range Performance       435      Type 2 CCS
# 31      Kia                    e-Niro 64 kWh       370      Type 2 CCS
# 61    Tesla   Model Y Long Range Performance       410      Type 2 CCS
# 64     Ford            Mustang Mach-E ER RWD       450      Type 2 CCS
# 66   Nissan                  e-NV200 Evalia        190  Type 1 CHAdeMO
# 69     Ford            Mustang Mach-E ER AWD       430      Type 2 CCS
# 75      Kia                    e-Niro 39 kWh       235      Type 2 CCS
# 78     Ford            Mustang Mach-E SR AWD       340      Type 2 CCS
# 83     Ford            Mustang Mach-E SR RWD       360      Type 2 CCS
#
#    BodyStyle  PriceEuro
# 0      Sedan      55480
# 8      Sedan      46380
# 14  Liftback      34459
# 21       SUV      58620
# 24     Sedan      61480
# 31       SUV      38105
# 61       SUV      65620
# 64       SUV      54475
# 66       SPV      33246
# 69       SUV      62900
# 75       SUV      34400
# 78       SUV      54000
# 83       SUV      46900

# %%
df_electric2['model_year'] = 2024

# %%
df_electric2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       13 non-null     object
#  1   Model       13 non-null     object
#  2   Range_Km    13 non-null     int64
#  3   PlugType    13 non-null     object
#  4   BodyStyle   13 non-null     object
#  5   PriceEuro   13 non-null     int64
#  6   model_year  13 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 832.0+ bytes

# %%
#Renombramos las columnas 
df_electric2.rename(columns={'Range_Km': 'range_km', 'PlugType': 'plug_type', 'BodyStyle': 'vehicle_class', 'PriceEuro': 'price_euro'}, inplace=True)
df_electric2
# Out:
#        Brand                           Model  range_km       plug_type  \
# 0     Tesla    Model 3 Long Range Dual Motor       450      Type 2 CCS
# 8     Tesla      Model 3 Standard Range Plus       310      Type 2 CCS
# 14  Hyundai                   IONIQ Electric       250      Type 2 CCS
# 21    Tesla    Model Y Long Range Dual Motor       425      Type 2 CCS
# 24    Tesla   Model 3 Long Range Performance       435      Type 2 CCS
# 31      Kia                    e-Niro 64 kWh       370      Type 2 CCS
# 61    Tesla   Model Y Long Range Performance       410      Type 2 CCS
# 64     Ford            Mustang Mach-E ER RWD       450      Type 2 CCS
# 66   Nissan                  e-NV200 Evalia        190  Type 1 CHAdeMO
# 69     Ford            Mustang Mach-E ER AWD       430      Type 2 CCS
# 75      Kia                    e-Niro 39 kWh       235      Type 2 CCS
# 78     Ford            Mustang Mach-E SR AWD       340      Type 2 CCS
# 83     Ford            Mustang Mach-E SR RWD       360      Type 2 CCS
#
#    vehicle_class  price_euro  model_year
# 0          Sedan       55480        2024
# 8          Sedan       46380        2024
# 14      Liftback       34459        2024
# 21           SUV       58620        2024
# 24         Sedan       61480        2024
# 31           SUV       38105        2024
# 61           SUV       65620        2024
# 64           SUV       54475        2024
# 66           SPV       33246        2024
# 69           SUV       62900        2024
# 75           SUV       34400        2024
# 78           SUV       54000        2024
# 83           SUV       46900        2024

# %%
#agregamos columanas para poder mergear con otros datasets
df_electric2['vehicle_type'] = 'Electric'

# %%
#Reordenamos columnas 
df_electric3 = df_electric2.reindex(columns=['Brand', 'Model', 'model_year','vehicle_class','vehicle_type','range_km', 'plug_type', 'price_euro'])

# %%
df_electric3
# Out:
#        Brand                           Model  model_year vehicle_class  \
# 0     Tesla    Model 3 Long Range Dual Motor        2024         Sedan
# 8     Tesla      Model 3 Standard Range Plus        2024         Sedan
# 14  Hyundai                   IONIQ Electric        2024      Liftback
# 21    Tesla    Model Y Long Range Dual Motor        2024           SUV
# 24    Tesla   Model 3 Long Range Performance        2024         Sedan
# 31      Kia                    e-Niro 64 kWh        2024           SUV
# 61    Tesla   Model Y Long Range Performance        2024           SUV
# 64     Ford            Mustang Mach-E ER RWD        2024           SUV
# 66   Nissan                  e-NV200 Evalia         2024           SPV
# 69     Ford            Mustang Mach-E ER AWD        2024           SUV
# 75      Kia                    e-Niro 39 kWh        2024           SUV
# 78     Ford            Mustang Mach-E SR AWD        2024           SUV
# 83     Ford            Mustang Mach-E SR RWD        2024           SUV
#
#    vehicle_type  range_km       plug_type  price_euro
# 0      Electric       450      Type 2 CCS       55480
# 8      Electric       310      Type 2 CCS       46380
# 14     Electric       250      Type 2 CCS       34459
# 21     Electric       425      Type 2 CCS       58620
# 24     Electric       435      Type 2 CCS       61480
# 31     Electric       370      Type 2 CCS       38105
# 61     Electric       410      Type 2 CCS       65620
# 64     Electric       450      Type 2 CCS       54475
# 66     Electric       190  Type 1 CHAdeMO       33246
# 69     Electric       430      Type 2 CCS       62900
# 75     Electric       235      Type 2 CCS       34400
# 78     Electric       340      Type 2 CCS       54000
# 83     Electric       360      Type 2 CCS       46900

# %%
unique_brands = df_electric3['Brand'].unique()
print(unique_brands)
# Out:
# ['Tesla ' 'Hyundai ' 'Kia ' 'Ford ' 'Nissan ']

# %%
df_electric3['Brand'] = df_electric3['Brand'].str.rstrip()

# %%
#Exportamo el dataset a un nuevo archivo csv
df_electric3.to_csv('df_electric_2.csv', index=False, encoding='utf-8')
